# %%
# !pip install snowflake
import os
import pandas as pd
from dotenv import load_dotenv
import snowflake.connector
import datetime

start = datetime.datetime.now()

def get_snowflake_connection(env_path=None):
    if env_path:
        load_dotenv(dotenv_path=env_path)
    else:
        load_dotenv()

    password = os.getenv("SNOWFLAKE_PASSWORD")
    account = os.getenv("SNOWFLAKE_ACCOUNT")
    user = os.getenv("SNOWFLAKE_USER")
    warehouse = os.getenv("SNOWFLAKE_WAREHOUSE")
    database = os.getenv("SNOWFLAKE_DATABASE")
    schema = os.getenv("SNOWFLAKE_SCHEMA")
    role = os.getenv("SNOWFLAKE_ROLE")

    conn = snowflake.connector.connect(
        user=user,
        password=password,
        account=account,
        warehouse=warehouse,
        database=database,
        schema=schema,
        role=role,
    )
    return conn

# === Step 1: Load environment variables from a custom path ===
dotenv_path = r"../.env"
load_dotenv(dotenv_path=dotenv_path)

# === Step 2: Define file paths ===
local_folder = "../data/raw"
cleaned_folder = "../data/cleaned_csv"
os.makedirs(cleaned_folder, exist_ok=True)

# === Step 3: Clean and lowercase column names, convert datetimes, and save as gzipped CSV ===
for filename in os.listdir(local_folder):
    if filename.endswith(".parquet"):
        original_path = os.path.join(local_folder, filename)
        cleaned_path = os.path.join(cleaned_folder, filename.replace(".parquet", ".csv.gz"))

        df = pd.read_parquet(original_path)
        df.columns = [col.lower() for col in df.columns]

        # Convert datetime columns to ISO string format
        df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime']).dt.strftime('%Y-%m-%d %H:%M:%S')
        df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime']).dt.strftime('%Y-%m-%d %H:%M:%S')

        # Extract year and month from filename
        _, year, month = filename.split('.')[0].split('_')
        df['month'] = int(month)
        df['year'] = int(year)

        # Save as gzipped CSV
        df.to_csv(cleaned_path, index=False, compression="gzip")
        print(f"✅ Cleaned and saved: {cleaned_path}")

# === Step 4: Connect to Snowflake using utility function ===
conn = get_snowflake_connection(env_path=dotenv_path)
cursor = conn.cursor()
cursor.execute("DROP DATABASE IF EXISTS NYC_DATA")
cursor.execute("CREATE DATABASE NYC_DATA")
cursor.execute("USE DATABASE NYC_DATA")
cursor.execute("CREATE SCHEMA IF NOT EXISTS PUBLIC")
cursor.execute("USE SCHEMA PUBLIC")

# === Step 5: Create table (updated to match cleaned CSV schema) ===
cursor.execute(
    """
CREATE OR REPLACE TABLE yellow_taxi_data_raw (
    vendorid INTEGER,
    tpep_pickup_datetime TIMESTAMP,
    tpep_dropoff_datetime TIMESTAMP,
    passenger_count FLOAT,
    trip_distance FLOAT,
    ratecodeid FLOAT,
    store_and_fwd_flag STRING,
    pulocationid INTEGER,
    dolocationid INTEGER,
    payment_type INTEGER,
    fare_amount FLOAT,
    extra FLOAT,
    mta_tax FLOAT,
    tip_amount FLOAT,
    tolls_amount FLOAT,
    improvement_surcharge FLOAT,
    total_amount FLOAT,
    congestion_surcharge FLOAT,
    airport_fee FLOAT,
    month INTEGER,
    year INTEGER
)
"""
)

# === Step 6: Create file format, stage, and upload cleaned gzipped CSV files ===
cursor.execute("""
    CREATE OR REPLACE FILE FORMAT nyc_csv_format
    TYPE = 'CSV'
    FIELD_OPTIONALLY_ENCLOSED_BY = '"'
    PARSE_HEADER = TRUE
""")
cursor.execute("CREATE OR REPLACE STAGE nyc_taxi_stage FILE_FORMAT = nyc_csv_format")
cursor.execute("REMOVE @nyc_taxi_stage")
print("🧹 Cleared stage: nyc_taxi_stage")

for filename in os.listdir(cleaned_folder):
    if filename.endswith(".csv.gz"):
        full_path = os.path.abspath(os.path.join(cleaned_folder, filename))
        put_command = f"PUT file://{full_path} @nyc_taxi_stage OVERWRITE = TRUE"
        print(f"⬆️ Uploading: {filename}")
        cursor.execute(put_command)

# === Step 7: Load data into the table from stage ===
cursor.execute(
    """
COPY INTO yellow_taxi_data_raw
FROM @nyc_taxi_stage
MATCH_BY_COLUMN_NAME = CASE_INSENSITIVE
"""
)

print("✅ All data loaded into Snowflake!")

# === Step 8: Close the connection ===
cursor.close()
conn.close()

end = datetime.datetime.now()
duration = end - start
minutes = duration.total_seconds() / 60

print("Duration:", duration)
print("Duration in minutes:", minutes)
# Out:
# Collecting snowflake
#   Downloading snowflake-1.4.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting snowflake-core==1.4.0 (from snowflake)
#   Downloading snowflake_core-1.4.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting snowflake-legacy (from snowflake)
#   Downloading snowflake_legacy-1.0.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pydantic>=2 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-core==1.4.0->snowflake) (2.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-core==1.4.0->snowflake) (2.9.0.post0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-core==1.4.0->snowflake) (6.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-core==1.4.0->snowflake) (2.32.3)
# Collecting snowflake-connector-python (from snowflake-core==1.4.0->snowflake)
#   Downloading snowflake_connector_python-3.15.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (70 kB)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-core==1.4.0->snowflake) (2.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2->snowflake-core==1.4.0->snowflake) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2->snowflake-core==1.4.0->snowflake) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic>=2->snowflake-core==1.4.0->snowflake) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->snowflake-core==1.4.0->snowflake) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->snowflake-core==1.4.0->snowflake) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->snowflake-core==1.4.0->snowflake) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->snowflake-core==1.4.0->snowflake) (2025.1.31)
# Collecting asn1crypto<2.0.0,>0.24.0 (from snowflake-connector-python->snowflake-core==1.4.0->snowflake)
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: boto3>=1.24 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (1.37.5)
# Requirement already satisfied: botocore>=1.24 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (1.37.5)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (1.17.1)
# Requirement already satisfied: cryptography>=3.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (44.0.1)
# Collecting pyOpenSSL<26.0.0,>=22.0.0 (from snowflake-connector-python->snowflake-core==1.4.0->snowflake)
#   Downloading pyOpenSSL-25.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pyjwt<3.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (2.10.1)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (2024.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (24.2)
# Requirement already satisfied: filelock<4,>=3.5 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from snowflake-connector-python->snowflake-core==1.4.0->snowflake) (3.10.0)
# Collecting tomlkit (from snowflake-connector-python->snowflake-core==1.4.0->snowflake)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python->snowflake-core==1.4.0->snowflake) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from boto3>=1.24->snowflake-connector-python->snowflake-core==1.4.0->snowflake) (0.11.3)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python->snowflake-core==1.4.0->snowflake) (2.21)
# Downloading snowflake-1.4.0-py3-none-any.whl (5.6 kB)
# Downloading snowflake_core-1.4.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.5 MB/s eta 0:00:00a 0:00:01
# Downloading snowflake_legacy-1.0.0-py3-none-any.whl (3.1 kB)
# Downloading snowflake_connector_python-3.15.0-cp311-cp311-macosx_11_0_arm64.whl (989 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.3/989.3 kB 41.2 MB/s eta 0:00:00
# Downloading asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
# Downloading pyOpenSSL-25.0.0-py3-none-any.whl (56 kB)
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Installing collected packages: asn1crypto, tomlkit, snowflake-legacy, pyOpenSSL, snowflake-connector-python, snowflake-core, snowflake
# Successfully installed asn1crypto-1.5.1 pyOpenSSL-25.0.0 snowflake-1.4.0 snowflake-connector-python-3.15.0 snowflake-core-1.4.0 snowflake-legacy-1.0.0 tomlkit-0.13.2
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_11.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_01.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_08.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_03.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_09.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_02.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_12.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_10.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_10.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_12.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_02.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_09.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_03.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_08.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_01.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_11.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_04.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_06.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_07.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_05.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_05.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_07.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2023_06.csv.gz
# ✅ Cleaned and saved: ../data/cleaned_csv/rides_2024_04.csv.gz
# 🧹 Cleared stage: nyc_taxi_stage
# ⬆️ Uploading: rides_2024_07.csv.gz
# ⬆️ Uploading: rides_2023_03.csv.gz
# ⬆️ Uploading: rides_2023_11.csv.gz
# ⬆️ Uploading: rides_2024_09.csv.gz
# ⬆️ Uploading: rides_2023_01.csv.gz
# ⬆️ Uploading: rides_2024_05.csv.gz
# ⬆️ Uploading: rides_2023_05.csv.gz
# ⬆️ Uploading: rides_2024_01.csv.gz
# ⬆️ Uploading: rides_2023_09.csv.gz
# ⬆️ Uploading: rides_2024_11.csv.gz
# ⬆️ Uploading: rides_2024_03.csv.gz
# ⬆️ Uploading: rides_2023_07.csv.gz
# ⬆️ Uploading: rides_2023_02.csv.gz
# ⬆️ Uploading: rides_2024_06.csv.gz
# ⬆️ Uploading: rides_2023_10.csv.gz
# ⬆️ Uploading: rides_2024_08.csv.gz
# ⬆️ Uploading: rides_2023_12.csv.gz
# ⬆️ Uploading: rides_2024_04.csv.gz
# ⬆️ Uploading: rides_2023_04.csv.gz
# ⬆️ Uploading: rides_2023_08.csv.gz
# ⬆️ Uploading: rides_2024_12.csv.gz
# ⬆️ Uploading: rides_2024_10.csv.gz
# ⬆️ Uploading: rides_2023_06.csv.gz
# ⬆️ Uploading: rides_2024_02.csv.gz
# ✅ All data loaded into Snowflake!
# Duration: 0:41:14.168519
# Duration in minutes: 41.23614198333333
